# %% [markdown]
# <a href="https://colab.research.google.com/github/DeeDom50/Python/blob/main/EET207-Applied-Engineering-Programming/week4/GuidedPractice_StringsandDictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Guided Practice String Methods and Dictionaries
#
# ### Try each of the Codes by pressing the Play button. You can modify the code and run again to see the outputs. Activities that need to be completed by the student are numbered.
# ### Answer the questions and download your completed activity with full outputs as a .pynb and a .pdf file. Use the Print option in the web browser to download the .pdf file. In your Chrome browser, press CTRL+P and select Set the Destination to "Save as PDF" or "Print to PDF" or the apropriate selection based on your computer. Save the file and submit your .pdf file in Canvas. A video on this process can be viewed using this [link](https://ecpi.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=2c60ba53-b182-4dd2-ba40-b12901260d39) or by running the code block below this. Thanks!

# %%
# Download Colab Notebook as .pdf and .ipynb Instructions

from IPython.display import HTML

HTML("""
<iframe src="https://ecpi.hosted.panopto.com/Panopto/Pages/Embed.aspx?id=2c60ba53-b182-4dd2-ba40-b12901260d39&autoplay=false&offerviewer=true&showtitle=true&showbrand=true&captions=false&interactivity=all"
height="950" width="1950" style="border: 1px solid #464646;" allowfullscreen allow="autoplay" aria-label="Panopto Embedded Video Player"></iframe>
""")

# %% [markdown]
# # Activity 4.1
# ## Modify the program below to demonstrate the following:
#
# 1. Modify the program below so it takes the input from the user.

# %%
# Activity 4.1
# This program calls the split method, using the
# '/' character as a separator.

def main():
    # Create a string with a date.
    date_string = input('Enter a date in the format mm/dd/yyyy: ')

    # Split the date.
    date_list = date_string.split('/')

    # Display each piece of the date.
    print('Month:', date_list[0])
    print('Day:', date_list[1])
    print('Year:', date_list[2])

# Call the main function.
main()
# Out:
# Enter a date in the format mm/dd/yyyy: 08/17/2026
# Month: 08
# Day: 17
# Year: 2026

# %% [markdown]
# # Activity 4.2
# ### **Refer to this documentation on the string method in Python https://docs.python.org/2.5/lib/string-methods.html**
# ## Modify the program below to demonstrate the following:
# 1. Prompt the user to enter a string.
# 2. Add if statements to check if the characters are all uppercase or lowercase.

# %%
# Activity 4.2
# This program demonstrates several string testing methods.

def main():
    # Get a string from the user.
    user_string = input('Enter a string: ')

    print('This is what I found about that string:')

    # Test the string.
    if user_string.isalnum():
        print('The string is alphanumeric.')

    if user_string.isupper():
        print('The string contains only uppercase characters.')

    if user_string.islower():
        print('The string contains only lowercase characters.')

    if user_string.isdigit():
        print('The string contains only digits.')

    if user_string.isalpha():
        print('The string contains only alphabetic characters.')

    if user_string.isspace():
        print('The string contains only whitespace characters.')

# Call the main function.
main()
# Out:
# Enter a string: aaaa
# This is what I found about that string:
# The string is alphanumeric.
# The string contains only lowercase characters.
# The string contains only alphabetic characters.

# %% [markdown]
# # Activity 4.3
# ### **Refer to this documentation on the string method in Python https://docs.python.org/2.5/lib/string-methods.html**
#
# ## Modify the program below to demonstrate the following:
# 1. Prompt user for a string return the lowercase and uppercase version of the string
# 2. Prompt the user for a second string.
# 3. Combines the two strings and prints them together in uppercase and lowercase.

# %%
# Activity 4.3
# This program demonstrates string manipulation.

def main():
    # Get a string from the user.
    string1 = input('Enter a string: ')

    # Display lowercase and uppercase versions.
    print('Lowercase:', string1.lower())
    print('Uppercase:', string1.upper())

    # Get another string from the user.
    string2 = input('Enter a second string: ')

    # Combine both strings.
    combined_string = string1 + ' ' + string2

    # Display both strings in uppercase and lowercase.
    print('Combined uppercase:', combined_string.upper())
    print('Combined lowercase:', combined_string.lower())

# Call the main function.
main()
# Out:
# Enter a string: Devante
# Lowercase: devante
# Uppercase: DEVANTE
# Enter a second string: Dominicci
# Combined uppercase: DEVANTE DOMINICCI
# Combined lowercase: devante dominicci

# %% [markdown]
# # Activity 4.4
# ## Modify the program below to demonstrate the following:
#
# 1. Change the program below to print nine rows of 'A' decreasing in length by removing one 'A' in each line.

# %%
# Activity 4.4
# This program demonstrates the repetition operator.

def main():
    # Print nine rows decreasing in length.
    for count in range(9, 0, -1):
        print('A' * count)

# Call the main function.
main()
# Out:
# AAAAAAAAA
# AAAAAAAA
# AAAAAAA
# AAAAAA
# AAAAA
# AAAA
# AAA
# AA
# A

# %% [markdown]
# # Activity 4.5
# ## Modify the program below to demonstrate the following:
#
# 1. User adds two courses.
# >Their course codes are HUM101, PHY101. \
# >Their room numbers are: 2200, 3300 respectively. \
# >Instructors for the courses are Heidegger and Bohrs respectively. \
# >Meeting times for the courses are: 10:00am and 11:00am respectively.

# %%
def main():
    # Initialize dictionaries
    rooms = {'CS101': 3004, 'CS102': 4501, 'CS103': 6755,
             'NT110': 1244, 'CM241': 1411,
             'HUM101': 2200, 'PHY101': 3300}

    instructors = {'CS101': 'Haynes', 'CS102': 'Alvarado',
                   'CS103': 'Rich', 'NT110': 'Burke',
                   'CM241': 'Lee',
                   'HUM101': 'Heidegger', 'PHY101': 'Bohrs'}

    times = {'CS101': '8:00 am', 'CS102': '9:00 am',
             'CS103': '10:00 am', 'NT110': '11:00 am',
             'CM241': '12:00 pm',
             'HUM101': '10:00 am', 'PHY101': '11:00 am'}

    course = input('Enter a course number: ')
    print()

    if course not in rooms:
        print(course, 'is an invalid course number.')
    else:
        print('The details for course', course, 'are:')
        print('Room:', rooms[course])
        print('Instructor:', instructors[course])
        print('Time:', times[course])

# Call the main function.
main()
# Out:
# Enter a course number: HUM101
#
# The details for course HUM101 are:
# Room: 2200
# Instructor: Heidegger
# Time: 10:00 am

# %% [markdown]
# # Activity 4.6
# ## Modify the program below to demonstrate the following:
#
# ### **Refer to page: 475 in the textbook for methods pertaining to Dictionaries.**
#
# 1. Use the pop method to remove one of the entries in the dictionary in Deliverable 4.5.
# 2. Use the get method to find all the value pair for a course code
# 3. Use the keys method to print all key values associated with all values in each dictionary.

# %%
# Activity 4.6

def main():
    # Initialize dictionaries
    rooms = {'CS101': 3004, 'CS102': 4501, 'CS103': 6755,
             'NT110': 1244, 'CM241': 1411, 'HUM101': 2200,
             'PHY101': 3300}

    instructors = {'CS101': 'Haynes', 'CS102': 'Alvarado',
                   'CS103': 'Rich', 'NT110': 'Burke',
                   'CM241': 'Lee', 'HUM101': 'Heidegger',
                   'PHY101': 'Bohrs'}

    times = {'CS101': '8:00 am', 'CS102': '9:00 am',
             'CS103': '10:00 am', 'NT110': '11:00 am',
             'CM241': '12:00 pm', 'HUM101': '10:00 am',
             'PHY101': '11:00 am'}

    # Display Initial Dictionary Values
    print("Initial Dictionaries\n")

    print("Rooms")
    for key, value in rooms.items():
        print(f'{key}: {value}')

    print("\nTimes")
    for key, value in times.items():
        print(f'{key}: {value}')

    print("\nInstructors")
    for key, value in instructors.items():
        print(f'{key}: {value}')

    print()

    # Use pop method to remove a course
    course_pop = input('Which course do you want to remove: ').upper()

    if course_pop in rooms:
        rooms.pop(course_pop)
        instructors.pop(course_pop)
        times.pop(course_pop)
        print(course_pop, 'was removed.')
    else:
        print(course_pop, 'is an invalid course number.')

    print()

    # Use get method to display value pairs for a course code key
    course_get = input('Which course do you want to see details for: ').upper()

    if course_get not in rooms:
        print(course_get, 'is an invalid course number.')
    else:
        print('Room:', rooms.get(course_get))
        print('Instructor:', instructors.get(course_get))
        print('Time:', times.get(course_get))

    print()

    # Use keys method to display all key value pairs
    print('Here are the Keys:\n')

    print('Rooms')
    for key in rooms.keys():
        print(key, ':', rooms[key])

    print('\nInstructors')
    for key in instructors.keys():
        print(key, ':', instructors[key])

    print('\nTimes')
    for key in times.keys():
        print(key, ':', times[key])


# Call the main function
main()
# Out:
# Initial Dictionaries
#
# Rooms
# CS101: 3004
# CS102: 4501
# CS103: 6755
# NT110: 1244
# CM241: 1411
# HUM101: 2200
# PHY101: 3300
#
# Times
# CS101: 8:00 am
# CS102: 9:00 am
# CS103: 10:00 am
# NT110: 11:00 am
# CM241: 12:00 pm
# HUM101: 10:00 am
# PHY101: 11:00 am
#
# Instructors
# CS101: Haynes
# CS102: Alvarado
# CS103: Rich
# NT110: Burke
# CM241: Lee
# HUM101: Heidegger
# PHY101: Bohrs
#
# Which course do you want to remove: HUM101
# HUM101 was removed.
#
# Which course do you want to see details for: PHY101
# Room: 3300
# Instructor: Bohrs
# Time: 11:00 am
#
# Here are the Keys:
#
# Rooms
# CS101 : 3004
# CS102 : 4501
# CS103 : 6755
# NT110 : 1244
# CM241 : 1411
# PHY101 : 3300
#
# Instructors
# CS101 : Haynes
# CS102 : Alvarado
# CS103 : Rich
# NT110 : Burke
# CM241 : Lee
# PHY101 : Bohrs
#
# Times
# CS101 : 8:00 am
# CS102 : 9:00 am
# CS103 : 10:00 am
# NT110 : 11:00 am
# CM241 : 12:00 pm
# PHY101 : 11:00 am

# %% [markdown]
# # Activity 4.7
# ### **Create an input file with a paragraph of text. You may copy paste a passage from the internet to create it. Save this text file in the same folder where you have saved this colab notebook file.**
# ## Modify the program below to demonstrate the following:
# 1. Prompt the user to input the path to that file.
# 2. Read and store the text in a set called 'unique_words'.
# 3. Use a for loop to read the unique_words set and add them to a dictionary called 'counter'.
# >***Note that the dictionary has already been setup in the code below.***
# 4. Read original file and find out how many times each word (stored in uniqure_words) occured in the original text.

# %%
# Mount drive first
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1205/915403197.py in <cell line: 0>()
#       1 # Mount drive first
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive', force_remount=True)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
# Activity 4.7

def main():
    # Set up empty dictionary
    counter = {}

    # Get input text
    input_name = input('Enter the path to the input file: ')

    # Read the text and store each word in a set named unique_words
    with open(input_name, 'r') as input_file:
        lines = input_file.read()
        words = lines.split()

    unique_words = set(words)

    # Add each unique word to dictionary with a counter of 0
    for word in unique_words:
        counter[word] = 0

    # Count unique word occurrences in original file
    with open(input_name, 'r') as input_file:
        lines = input_file.read()
        words = lines.split()

    # Add one for each occurrence of a unique word
    for word in words:
        if word in counter:
            counter[word] += 1

    # Display the results
    print('\nWord Counts:')
    for word, count in counter.items():
        print(word, ':', count)


# Call the main function
main()
# Out:
# Enter the path to the input file: /content/activity47_input.txt
#
# Word Counts:
# to : 1
# how : 1
# files, : 1
# count : 1
# Python : 4
# becomes : 1
# easier : 1
# more : 1
# also : 1
# problems. : 1
# read : 1
# and : 3
# programming : 2
# store : 1
# paragraph. : 1
# data, : 1
# language : 1
# a : 2
# process : 1
# information. : 1
# is : 1
# computers : 1
# file : 1
# in : 1
# practice, : 1
# for : 2
# learning : 1
# loops, : 1
# understand : 1
# useful : 2
# helps : 1
# students : 1
# practice : 1
# dictionaries, : 1
# solving : 1
# With : 1
# management. : 1
# sets, : 1
# words : 1
# Learning : 1
# can : 1
